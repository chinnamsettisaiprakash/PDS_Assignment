# %% [markdown]
# **Stage 1: Creating Folder Structure**

# %% [markdown]
# **Stage 2: Data Collection/Preprocessing**
#
# In this stage, I would like to collect the data and preprocess it for analysis. This includes cleaning, normalizing, and transforming the data to make it ready for the next stages.
#
# **Workflow:**
#
# **Data Cleaning:** Check for null values.
#
# **Data Validation:** Ensure that data is valid and adheres to expected ranges for each attribute.

# %% [markdown]
# **Stage 3: Data Analysis/Modeling**
#
# In this stage, I would like to conduct exploratory data analysis (EDA) and modeling. The goal is to identify patterns, visualize relationships between variables, and build models to predict or classify frailty based on grip strength and other factors.
#
# **Workflow:**
#
# **Exploratory Data Analysis (EDA):** Visualize the relationships between features. Use histograms, scatter plots, correlation matrices, etc.

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('StudentsPerformance.csv')

# Show the first few rows of the dataset to understand its structure
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Checking for null values in the dataset
null_values = data.isnull().sum()

# Displaying the result
null_values
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# **Visualization Tasks:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# %%
# Set the aesthetics for seaborn plots
sns.set(style="whitegrid")

# %%
# 1. Gender vs. Math Score (Bar Plot)
plt.figure(figsize=(6, 4))
sns.barplot(x='gender', y='math score', data=data, palette=['#A1D6E2', '#1995AD'])
plt.title('Average Math Score by Gender')
plt.show()
# Out:
# <ipython-input-46-ed99c315fe1a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='gender', y='math score', data=data, palette=['#A1D6E2', '#1995AD'])

# %%
# 2. Gender Distribution of Students
gender_counts = data['gender'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['#7f8c8d', '#f1c40f'])
plt.title('Gender Distribution of Students')
plt.axis('equal')
plt.show()

# %%
# 3. Correlation Heatmap of Scores
# Create a custom color map using the two colors
custom_cmap = LinearSegmentedColormap.from_list('custom_cmap', ['#E74C3C', '#3498DB'])

# Plot the heatmap with the custom color map
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap=custom_cmap, fmt=".2f")
plt.title('Correlation Heatmap of Scores')
plt.show()

# %%
# 4 Distribution of math scores based on test preparation course completion
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='math score', hue='test preparation course', multiple='stack', palette = sns.color_palette("Accent"), kde=True)
plt.title('Distribution of Math Scores by Test Preparation Course')
plt.show()
# Out:
# <ipython-input-64-6ef4f9bda1e9>:3: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.histplot(data=data, x='math score', hue='test preparation course', multiple='stack', palette = sns.color_palette("Accent"), kde=True)

# %%
# 5. Scatter Plot of Math Score vs. Writing Score Colored by Gender
plt.figure(figsize=(8, 6))
sns.scatterplot(x='math score', y='writing score', hue='gender', data=data, palette=colors)
plt.title('Math Score vs. Writing Score by Gender')
plt.show()

# %% [markdown]
# **Explanation of the Visualizations and Their Analytical Utility:**
#
# **Distribution of Students by Gender:**
#
# **Type:** Count Plot
#
# **Analysis:** This plot provides a quick overview of the number of male and female students in the dataset. This helps to understand gender representation and informs decisions about gender-based comparisons in further analysis.
#
# **Why Easier:** Identifying gender disparities in sample sizes can guide how data should be handled (e.g., balancing datasets for fairness in gender-based studies).
#
# **Math Scores by Gender (Box Plot):**
#
# **Type: Box Plot**
#
# **Analysis:** The box plot compares the distribution of math scores across gender, allowing you to visually assess differences in central tendency (e.g., median) and variability (e.g., range, interquartile range) between males and females.
#
# **Why Easier:** Quickly identifies if one gender tends to score higher in math and if there are outliers. This type of visualization is useful in spotting patterns of performance differences and variability.
#
# **Math Score vs. Reading Score by Gender (Scatter Plot):**
#
# **Type:** Scatter Plot
#
# **Analysis:** This plot visualizes the relationship between math and reading scores and includes a color-coded gender dimension. It allows for quick identification of correlation between the two scores and any noticeable trends by gender.
#
# **Why Easier:** Enables detection of a correlation between two variables and highlights gender differences in performance patterns, helping in understanding how performance in one subject may influence performance in another.
#
# **Average Scores by Parental Level of Education (Bar Plot):**
#
# **Type:** Bar Plot
#
# **Analysis:** This bar plot shows how the average math, reading, and writing scores vary based on the parental level of education. It reveals which parental education categories are associated with higher or lower average scores.
#
# **Why Easier:** It simplifies comparisons across multiple categories (parental education levels) and subjects. This helps to investigate the influence of socioeconomic factors on academic performance.
#
# **Distribution of Math Scores by Test Preparation Course (Histogram):**
#
# **Type:** Histogram with KDE (Kernel Density Estimate)
#
# **Analysis:** This plot shows the distribution of math scores for students who completed or did not complete a test preparation course. It allows for comparison of performance outcomes between these two groups.
# Why Easier: Visually shows the impact of test preparation courses on math scores, making it easy to assess whether preparation courses lead to significantly different performance outcomes.
